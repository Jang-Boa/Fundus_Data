# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
img = np.array(Image.open('./data/2.jpg'))
plt.imshow(img)

# %%
from preprocess import histogram_matching
new_img = histogram_matching.color_adjustment(img)
plt.imshow(new_img)
