# %% [markdown]
# ### Vessel Extraction

# %%
image_path = './data/4.png'
from extract_vessel import get_vessel_mask
image, pred_mask = get_vessel_mask(image_path)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image)
plt.axis('off')
plt.subplot(1,2,2)
plt.title(f"Predict")
plt.imshow(pred_mask, cmap='gray')
plt.axis('off')
plt.show()
